# %% [markdown]
# # Soybean Heat-Wave RGB Maps — 3 Crop Models
# ### DSSAT (CROPGRO) vs BioCro vs WOFOST  |  2-D Bivariate Colour Mapping
#
# | Corner | Colour | Meaning |
# |--------|--------|---------|
# | LL | **Magenta** | DSSAT (CROPGRO) dominates |
# | LR | **Blue** | BioCro dominates |
# | UL | **Green** | WOFOST dominates |
# | UR | **Yellow** | Both BioCro & WOFOST dominate |
# | Centre | **White** | Models agree (near-zero relative difference) |
#
# Each scenario pair produces a **3-panel figure**:
# 1. Mean percent-difference map
# 2. STD percent-difference map
# 3. Reference boundaries
#
# ---

# %% [markdown]
# ## 1. Configuration & Imports

# %%
import os
import glob
import numpy as np
import pandas as pd
import geopandas as gpd
import matplotlib as mpl
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1.inset_locator import inset_axes

mpl.rcParams['font.family'] = 'Arial'

# ── Data paths ──────────────────────────────────────────────
_nb_dir  = os.path.dirname(os.path.abspath('__file__'))
DATA_DIR = os.path.normpath(os.path.join(_nb_dir, '..', 'data'))

# GeoJSON spatial layers live in the top-level data/ directory
PATHS = {
    'city_mask':     os.path.join(DATA_DIR, '4k_grid_city_only.geojson'),
    'temp_shp':      os.path.join(DATA_DIR, 'COMBINED_DIST.geojson'),
    'us_states':     os.path.join(DATA_DIR, 'us_states_for_map.geojson'),
    'counties_usa':  os.path.join(DATA_DIR, 'counties_usa_for_map.geojson'),
    'ag_60':         os.path.join(DATA_DIR, 'ag_dis_n.geojson'),
    'ag_90':         os.path.join(DATA_DIR, 'ag_dis_s.geojson'),
    'combined_dist': os.path.join(DATA_DIR, 'COMBINED_DIST_with_county .geojson'),
    'grid':          os.path.join(DATA_DIR, '4km_2025_grid_pol.geojson'),
}

# Soybean crop-model CSV data lives in Figures/data/
FIG_DATA_DIR = os.path.normpath(os.path.join(_nb_dir, 'data'))
DSSAT_DIR    = os.path.join(FIG_DATA_DIR, 'DSSAT')
BIOCRO_DIR   = os.path.join(FIG_DATA_DIR, 'Soybean-BioCro')
WOFOST_DIR   = os.path.join(FIG_DATA_DIR, 'WOFOST')

OUTPUT_DIR = os.path.join(DATA_DIR, 'output_maps_soybean')
os.makedirs(OUTPUT_DIR, exist_ok=True)

# ── Plot styling ───────────────────────────────────────────
STYLE = {
    'markersize':       3,
    'marker_lw':        1.5,
    'lw_states':        2.5,
    'lw_counties':      0.5,
    'lw_boundary':      2.0,
    'color_borders':    'black',
    'color_counties':   'gray',
    'facecolor_bg':     'lightgray',
    'city_face':        '#222222',
    'city_edge':        'black',
    'zoom_main':        0.20,
    'zoom_inset':       10,
    'fig_size':         (24, 8),
    'dpi':              300,
}

print(f'DATA_DIR     = {DATA_DIR}')
print(f'FIG_DATA_DIR = {FIG_DATA_DIR}')
print(f'DSSAT_DIR    = {DSSAT_DIR}')
print(f'BIOCRO_DIR   = {BIOCRO_DIR}')
print(f'WOFOST_DIR   = {WOFOST_DIR}')
print(f'OUTPUT       = {OUTPUT_DIR}')
print('Configuration OK')
# Out:
# DATA_DIR     = c:\BioCro_DSSAT_WOFOST_Egorov_etal_paper-main\data
# FIG_DATA_DIR = c:\BioCro_DSSAT_WOFOST_Egorov_etal_paper-main\Figures\data
# DSSAT_DIR    = c:\BioCro_DSSAT_WOFOST_Egorov_etal_paper-main\Figures\data\DSSAT
# BIOCRO_DIR   = c:\BioCro_DSSAT_WOFOST_Egorov_etal_paper-main\Figures\data\Soybean-BioCro
# WOFOST_DIR   = c:\BioCro_DSSAT_WOFOST_Egorov_etal_paper-main\Figures\data\WOFOST
# OUTPUT       = c:\BioCro_DSSAT_WOFOST_Egorov_etal_paper-main\data\output_maps_soybean
# Configuration OK

# %% [markdown]
# ## 2. Helper Functions
#
# - **`dx_dy_to_rgb`** — 2-D bivariate Gaussian blend (Magenta / Blue / Green / Yellow corners)
# - **`rgb_to_hex_safe`** — Convert RGB float array → hex strings
# - **`process_yield_data`** — Read per-year CSVs (skip 2000), merge on real_id, compute mean & std
# - **`compute_diffs`** — Year-by-year difference & percent-difference
# - **`set_zoom`** / **`add_inset`** — Map framing utilities

# %%
# ── 2-D Bivariate colour corners ──────────────────────────
C_MAGENTA = np.array([255,   0, 255]) / 255.0   # DSSAT (CROPGRO) dominant
C_BLUE    = np.array([0,     0, 255]) / 255.0   # BioCro dominant
C_GREEN   = np.array([0,   255,   0]) / 255.0   # WOFOST dominant
C_YELLOW  = np.array([255, 255,   0]) / 255.0   # BioCro + WOFOST dominant


def dx_dy_to_rgb(dx, dy, sigma=0.05):
    """2-D bivariate Gaussian blend:
       Magenta (LL) / Blue (LR) / Green (UL) / Yellow (UR) corners,
       White at centre (models agree)."""
    wx = np.clip((dx + 1) / 2, 0, 1)[..., None]
    wy = np.clip((dy + 1) / 2, 0, 1)[..., None]
    base = (
        (1 - wx) * (1 - wy) * C_MAGENTA +
        wx       * (1 - wy) * C_BLUE +
        (1 - wx) * wy       * C_GREEN +
        wx       * wy       * C_YELLOW
    )
    r2  = dx**2 + dy**2
    w0  = np.exp(-r2 / sigma**2)[..., None]
    return (1 - w0) * base + w0 * 1.0


def rgb_to_hex_safe(rgb_arr, nan_colour='#cccccc'):
    """Convert (N, 3) float RGB array to flat array of hex strings."""
    flat = np.reshape(rgb_arr, (-1, 3))
    out  = []
    for triplet in flat:
        if np.isnan(triplet).any():
            out.append(nan_colour)
        else:
            r, g, b = np.clip(triplet * 255, 0, 255).astype(int)
            out.append(f'#{r:02x}{g:02x}{b:02x}')
    return np.array(out)


def set_zoom(ax, gdf, padding):
    """Set axis limits from GeoDataFrame bounds + fractional padding."""
    xmin, ymin, xmax, ymax = gdf.total_bounds
    dx, dy = (xmax - xmin) * padding, (ymax - ymin) * padding
    ax.set_xlim(xmin - dx, xmax + dx)
    ax.set_ylim(ymin - dy, ymax + dy)


def add_inset(parent_ax, district_gdf, states_gdf, ref_gdf, zoom_pad):
    """Add a small locator inset map to the upper-right of *parent_ax*."""
    axins = inset_axes(parent_ax, width=1.5, height=1.5, loc='upper right',
                       borderpad=0, bbox_to_anchor=(1.00, 1.033),
                       bbox_transform=parent_ax.transAxes)
    district_gdf.to_crs(epsg=4326).plot(ax=axins, color='black',
                                         edgecolor='black', alpha=0.5)
    xmin, ymin, xmax, ymax = ref_gdf.total_bounds
    xp = (xmax - xmin) * zoom_pad
    yp = (ymax - ymin) * zoom_pad
    axins.set_xlim(xmin - xp, xmax + xp)
    axins.set_ylim(ymin - yp, ymax + yp)
    states_gdf.to_crs(epsg=4326).plot(ax=axins, color='lightgray',
                                       edgecolor='black', alpha=1.0)
    ref_gdf.plot(ax=axins, color='lightgray', edgecolor='red', alpha=1.0)
    axins.set_xticks([]); axins.set_yticks([]); axins.set_title('')
    return axins


def compute_diffs(df_a, df_b):
    """Year-by-year diff & percent-diff between two GeoDataFrames.
    Returns a GeoDataFrame with mean_difference, mean_percent_difference,
    mean_difference_STD columns."""
    year_cols_a = {c[-4:]: c for c in df_a.columns if c[-4:].isdigit()}
    year_cols_b = {c[-4:]: c for c in df_b.columns if c[-4:].isdigit()}
    common = sorted(set(year_cols_a) & set(year_cols_b))

    result = pd.DataFrame({'real_id': df_a['real_id']})
    diff_cols, pct_cols = [], []

    for yr in common:
        ca, cb = year_cols_a[yr], year_cols_b[yr]
        diff = df_a[ca] - df_b[cb]
        pct  = ((diff / df_b[cb]) * 100).replace([np.inf, -np.inf], pd.NA)
        result[f'diff_{yr}']    = diff
        result[f'percent_{yr}'] = pct
        diff_cols.append(f'diff_{yr}')
        pct_cols.append(f'percent_{yr}')

    result['mean_difference']         = result[diff_cols].mean(axis=1)
    result['mean_percent_difference'] = result[pct_cols].mean(axis=1)
    result['mean_difference_STD']     = result[pct_cols].std(axis=1)

    result['Col_A_pattern'] = year_cols_a[common[0]] if common else None
    result['Col_B_pattern'] = year_cols_b[common[0]] if common else None

    result = result.merge(df_a[['real_id', 'geometry']], on='real_id')
    return gpd.GeoDataFrame(result, geometry='geometry', crs=df_a.crs)


def process_yield_data(input_directory):
    """Read per-year CSVs (skip 2000), merge on real_id, return summary CSV path."""
    dir_name    = os.path.basename(os.path.normpath(input_directory))
    output_file = os.path.join(input_directory,
                               f'{dir_name}_grain_yield_mean_with_years.csv')
    if os.path.exists(output_file):
        os.remove(output_file)

    csvs = [f for f in glob.glob(os.path.join(input_directory, '*.csv'))
            if '2000' not in os.path.basename(f)]
    if not csvs:
        print(f'  [!] No CSVs in {input_directory}')
        return None

    frames = []
    for fp in csvs:
        try:
            df = pd.read_csv(fp)
            if 'real_id' not in df.columns and 'id' in df.columns:
                df.rename(columns={'id': 'real_id'}, inplace=True)
            if 'real_id' not in df.columns:
                continue
            ycol = 'Grain' if 'Grain' in df.columns else (
                   'yield' if 'yield' in df.columns else None)
            if ycol is None:
                continue
            suffix = os.path.splitext(os.path.basename(fp))[0].replace('.', '_')
            df = df[['real_id', ycol]].rename(columns={ycol: f'{ycol}_{suffix}'})
            frames.append(df)
        except Exception as e:
            print(f'  [!] Error reading {fp}: {e}')

    if not frames:
        return None

    merged = frames[0]
    for f in frames[1:]:
        merged = pd.merge(merged, f, on='real_id', how='outer')

    ycols = [c for c in merged.columns if c.startswith('Grain_') or c.startswith('yield_')]
    merged['Yield_mean'] = merged[ycols].mean(axis=1)
    merged['Yield_std']  = merged[ycols].std(axis=1)
    merged.to_csv(output_file, index=False)
    return output_file


print('Helper functions loaded')
# Out:
# Helper functions loaded

# %% [markdown]
# ## 3. Load Spatial Layers

# %%
city_mask    = gpd.read_file(PATHS['city_mask']).set_crs(epsg=4326)
temp_shp     = gpd.read_file(PATHS['temp_shp']).to_crs(epsg=4326)
us_states    = gpd.read_file(PATHS['us_states']).to_crs(epsg=4326)
counties_usa = gpd.read_file(PATHS['counties_usa']).to_crs(epsg=4326)
district_60  = gpd.read_file(PATHS['ag_60']).set_crs(epsg=4326).to_crs(epsg=4326)
district_90  = gpd.read_file(PATHS['ag_90']).set_crs(epsg=4326).to_crs(epsg=4326)
ref_districts = gpd.read_file(PATHS['combined_dist']).set_crs(epsg=4326).to_crs(epsg=4326)

grid_file = gpd.read_file(PATHS['grid']).set_crs(epsg=4326).to_crs(epsg=4326)
grid_file['Id'] = grid_file['ORIG_FID']

print(f'Grid cells : {len(grid_file):,}')
print(f'US states  : {len(us_states)}')
print(f'Counties   : {len(counties_usa)}')
print('Spatial layers loaded')
# Out:
# Grid cells : 2,425
# US states  : 51
# Counties   : 51
# Spatial layers loaded

# %% [markdown]
# ## 4. Scenario Pairs
#
# Each row is `[baseline_H0, heatwave_Hx]` — same CO2 & temperature offset,
# comparing **no-heatwave** vs **heatwave** conditions across all 3 CO2 levels
# (400, 600, 800 ppm) and 4 temperature levels (TBL, +1.5, +2.5, +4.0 C).

# %%
SCENARIO_PAIRS = [
    # ──────────── 400 ppm ────────────
    # ── Baseline temperature (TBL) ──
    ['1S_C400TBLH0',   '13S_C400TBLH1'],
    ['1S_C400TBLH0',   '25S_C400TBLH2'],
    ['1S_C400TBLH0',   '37S_C400TBLH3'],
    ['1S_C400TBLH0',   '49S_C400TBLH123'],
    # ── +1.5 C ──
    ['2S_C400T1.5H0',  '14S_C400T1.5H1'],
    ['2S_C400T1.5H0',  '26S_C400T1.5H2'],
    ['2S_C400T1.5H0',  '38S_C400T1.5H3'],
    ['2S_C400T1.5H0',  '50S_C400T1.5H123'],
    # ── +2.5 C ──
    ['3S_C400T2.5H0',  '15S_C400T2.5H1'],
    ['3S_C400T2.5H0',  '27S_C400T2.5H2'],
    ['3S_C400T2.5H0',  '39S_C400T2.5H3'],
    ['3S_C400T2.5H0',  '51S_C400T2.5H123'],
    # ── +4.0 C ──
    ['4S_C400T4H0',    '16S_C400T4H1'],
    ['4S_C400T4H0',    '28S_C400T4H2'],
    ['4S_C400T4H0',    '40S_C400T4H3'],
    ['4S_C400T4H0',    '52S_C400T4H123'],

    # ──────────── 600 ppm ────────────
    # ── Baseline temperature (TBL) ──
    ['5S_C600TBLH0',   '17S_C600TBLH1'],
    ['5S_C600TBLH0',   '29S_C600TBLH2'],
    ['5S_C600TBLH0',   '41S_C600TBLH3'],
    ['5S_C600TBLH0',   '53S_C600TBLH123'],
    # ── +1.5 C ──
    ['6S_C600T1.5H0',  '18S_C600T1.5H1'],
    ['6S_C600T1.5H0',  '30S_C600T1.5H2'],
    ['6S_C600T1.5H0',  '42S_C600T1.5H3'],
    ['6S_C600T1.5H0',  '54S_C600T1.5H123'],
    # ── +2.5 C ──
    ['7S_C600T2.5H0',  '19S_C600T2.5H1'],
    ['7S_C600T2.5H0',  '31S_C600T2.5H2'],
    ['7S_C600T2.5H0',  '43S_C600T2.5H3'],
    ['7S_C600T2.5H0',  '55S_C600T2.5H123'],
    # ── +4.0 C ──
    ['8S_C600T4H0',    '20S_C600T4H1'],
    ['8S_C600T4H0',    '32S_C600T4H2'],
    ['8S_C600T4H0',    '44S_C600T4H3'],
    ['8S_C600T4H0',    '56S_C600T4H123'],

    # ──────────── 800 ppm ────────────
    # ── Baseline temperature (TBL) ──
    ['9S_C800TBLH0',   '21S_C800TBLH1'],
    ['9S_C800TBLH0',   '33S_C800TBLH2'],
    ['9S_C800TBLH0',   '45S_C800TBLH3'],
    ['9S_C800TBLH0',   '57S_C800TBLH123'],
    # ── +1.5 C ──
    ['10S_C800T1.5H0', '22S_C800T1.5H1'],
    ['10S_C800T1.5H0', '34S_C800T1.5H2'],
    ['10S_C800T1.5H0', '46S_C800T1.5H3'],
    ['10S_C800T1.5H0', '58S_C800T1.5H123'],
    # ── +2.5 C ──
    ['11S_C800T2.5H0', '23S_C800T2.5H1'],
    ['11S_C800T2.5H0', '35S_C800T2.5H2'],
    ['11S_C800T2.5H0', '47S_C800T2.5H3'],
    ['11S_C800T2.5H0', '59S_C800T2.5H123'],
    # ── +4.0 C ──
    ['12S_C800T4H0',   '24S_C800T4H1'],
    ['12S_C800T4H0',   '36S_C800T4H2'],
    ['12S_C800T4H0',   '48S_C800T4H3'],
    ['12S_C800T4H0',   '60S_C800T4H123'],
]

print(f'{len(SCENARIO_PAIRS)} scenario pairs defined')
# Out:
# 48 scenario pairs defined

# %% [markdown]
# ## 5. Plotting Helpers
#
# Reusable functions that draw a single map panel and its overlay layers.

# %%
def draw_base_layers(ax):
    """Draw city mask on base layer."""
    city_mask.plot(ax=ax, facecolor=STYLE['city_face'],
                  edgecolor=STYLE['city_edge'],
                  linewidth=STYLE['lw_counties'], zorder=1, alpha=0.4)


def draw_overlays(ax):
    """Draw county/state borders and study-area boundary on top."""
    counties_usa.plot(ax=ax, facecolor='none',
                     edgecolor=STYLE['color_borders'],
                     linewidth=STYLE['lw_counties'], zorder=15)
    us_states.plot(ax=ax, facecolor='none',
                  edgecolor=STYLE['color_borders'],
                  linewidth=STYLE['lw_states'], zorder=15)
    temp_shp.plot(ax=ax, facecolor='none', edgecolor='black',
                 linewidth=STYLE['lw_boundary'], zorder=15)


def style_ax(ax, title):
    """Apply standard styling to a map axis."""
    ax.set_title(title, fontsize=14)
    ax.set_facecolor(STYLE['facecolor_bg'])
    ax.set_xlabel('Longitude')
    ax.set_ylabel('Latitude')
    set_zoom(ax, ref_districts, STYLE['zoom_main'])


def plot_positive_dots(ax, pos_gdf):
    """Plot black centroid dots for cells where the stronger model is positive."""
    if pos_gdf.empty:
        return
    pts = pos_gdf.copy()
    pts['geometry'] = pts.centroid
    pts.plot(ax=ax, color='black', markersize=STYLE['markersize'],
             marker='o', linewidth=STYLE['marker_lw'], zorder=3)


def plot_colour_grid(ax, gdf, colour_col):
    """Plot the coloured grid cells."""
    gdf.plot(color=gdf[colour_col], edgecolor='black',
             linewidth=0.08, ax=ax, zorder=1)


print('Plotting helpers loaded')
# Out:
# Plotting helpers loaded

# %% [markdown]
# ## 6. Main Processing Loop
#
# For each scenario pair:
# 1. Read & merge yield CSVs for DSSAT, BioCro, and WOFOST
# 2. Compute per-year differences (heatwave minus baseline) for each model
# 3. Calculate 2-D relative difference → bivariate colour (dx = BioCro vs DSSAT, dy = WOFOST vs DSSAT)
# 4. Draw 3-panel figure (Mean | STD | Reference) and save

# %%
for idx, (name_A, name_B) in enumerate(SCENARIO_PAIRS):

    label = f'{name_B} - {name_A}'
    print(f'\n{"="*60}')
    print(f'Pair {idx:>2d}/{len(SCENARIO_PAIRS)}:  {label}')
    print(f'{"="*60}')

    # ── 1. Process yield CSVs ──────────────────────────────
    csv_dssat_A  = process_yield_data(os.path.join(DSSAT_DIR,  name_A))
    csv_dssat_B  = process_yield_data(os.path.join(DSSAT_DIR,  name_B))
    csv_biocro_A = process_yield_data(os.path.join(BIOCRO_DIR, name_A))
    csv_biocro_B = process_yield_data(os.path.join(BIOCRO_DIR, name_B))
    csv_wofost_A = process_yield_data(os.path.join(WOFOST_DIR, name_A))
    csv_wofost_B = process_yield_data(os.path.join(WOFOST_DIR, name_B))

    all_csvs = [csv_dssat_A, csv_dssat_B, csv_biocro_A, csv_biocro_B,
                csv_wofost_A, csv_wofost_B]
    if any(p is None for p in all_csvs):
        print('  Skipping — missing data')
        continue

    dssat_A  = grid_file.merge(pd.read_csv(csv_dssat_A),  left_on='id', right_on='real_id')
    dssat_B  = grid_file.merge(pd.read_csv(csv_dssat_B),  left_on='id', right_on='real_id')
    biocro_A = grid_file.merge(pd.read_csv(csv_biocro_A), left_on='id', right_on='real_id')
    biocro_B = grid_file.merge(pd.read_csv(csv_biocro_B), left_on='id', right_on='real_id')
    wofost_A = grid_file.merge(pd.read_csv(csv_wofost_A), left_on='id', right_on='real_id')
    wofost_B = grid_file.merge(pd.read_csv(csv_wofost_B), left_on='id', right_on='real_id')

    # Rename Grain_ columns to yield_ for BioCro consistency
    def rename_grain_to_yield(df):
        return df.rename(columns={
            col: col.replace("Grain_", "yield_")
            for col in df.columns
            if col.startswith("Grain_") and col[-4:].isdigit()
        })

    biocro_A = rename_grain_to_yield(biocro_A)
    biocro_B = rename_grain_to_yield(biocro_B)

    # ── 2. Compute diffs (heatwave - baseline) for each model ──
    D = compute_diffs(dssat_B,  dssat_A)
    B = compute_diffs(biocro_B, biocro_A)
    W = compute_diffs(wofost_B, wofost_A)

    # ── 3. Identify strongest model & positive-flag ────────
    merged = W.copy()
    merged['mean_W'] = W['mean_percent_difference']
    merged['mean_B'] = B['mean_percent_difference']
    merged['mean_D'] = D['mean_percent_difference']

    merged['mean_W_abs'] = merged['mean_W'].abs()
    merged['mean_B_abs'] = merged['mean_B'].abs()
    merged['mean_D_abs'] = merged['mean_D'].abs()

    merged['max_model'] = merged[['mean_W_abs', 'mean_B_abs', 'mean_D_abs']].idxmax(axis=1)
    merged['positive_flag'] = 'no'
    merged.loc[(merged['max_model'] == 'mean_W_abs') & (merged['mean_W'] > 0), 'positive_flag'] = 'yes'
    merged.loc[(merged['max_model'] == 'mean_B_abs') & (merged['mean_B'] > 0), 'positive_flag'] = 'yes'
    merged.loc[(merged['max_model'] == 'mean_D_abs') & (merged['mean_D'] > 0), 'positive_flag'] = 'yes'

    n_pos = (merged['positive_flag'] == 'yes').sum()
    print(f'  Grid cells: {len(merged):,}  |  Positive-flag: {n_pos}')

    # ── 4. Bivariate colour — MEAN ────────────────────────
    ref_mean = D['mean_percent_difference'].replace(0, np.nan)
    dx_mean  = ((B['mean_percent_difference'] - ref_mean) / ref_mean).clip(-1, 1)
    dy_mean  = ((W['mean_percent_difference'] - ref_mean) / ref_mean).clip(-1, 1)

    gdf_mean = D.copy()
    gdf_mean['color'] = rgb_to_hex_safe(dx_dy_to_rgb(dx_mean.to_numpy(), dy_mean.to_numpy()))

    merged = merged.to_crs(epsg=4326)
    gdf_pos = merged[merged['positive_flag'] == 'yes'].copy()

    # ── 5. Create single-panel figure (Mean only) ─────────
    fig, ax1 = plt.subplots(1, 1, figsize=(8, 8))

    # --- Panel 1: Mean ---
    draw_base_layers(ax1)
    plot_positive_dots(ax1, gdf_pos)
    plot_colour_grid(ax1, gdf_mean, 'color')
    draw_overlays(ax1)
    style_ax(ax1, f'{label}  mean')
    add_inset(ax1, district_60, us_states, ref_districts, STYLE['zoom_inset'])

    # ── Save ──────────────────────────────────────────────
    out_path = os.path.join(OUTPUT_DIR, f'{label}_plot_Delta_S.png')
    plt.savefig(out_path, dpi=STYLE['dpi'], bbox_inches='tight')
    plt.close(fig)
    print(f'  Saved: {out_path}')

print(f'\nDone — {len(SCENARIO_PAIRS)} pairs processed.')
# Out:
# ============================================================
# Pair  0/48:  13S_C400TBLH1 - 1S_C400TBLH0
# ============================================================
#   Grid cells: 2,423  |  Positive-flag: 0
#   Saved: c:\BioCro_DSSAT_WOFOST_Egorov_etal_paper-main\data\output_maps_soybean\13S_C400TBLH1 - 1S_C400TBLH0_plot_Delta_S.png
#
# ============================================================
# Pair  1/48:  25S_C400TBLH2 - 1S_C400TBLH0
# ============================================================
#   Grid cells: 2,423  |  Positive-flag: 0
#   Saved: c:\BioCro_DSSAT_WOFOST_Egorov_etal_paper-main\data\output_maps_soybean\25S_C400TBLH2 - 1S_C400TBLH0_plot_Delta_S.png
#
# ============================================================
# Pair  2/48:  37S_C400TBLH3 - 1S_C400TBLH0
# ============================================================
#   Grid cells: 2,423  |  Positive-flag: 12
# C:\Users\yaron\AppData\Local\Temp\ipykernel_4960\190363248.py:34: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   pts['geometry'] = pts.centroid
#   Saved: c:\BioCro_DSSAT_WOFOST_Egorov_etal_paper-main\data\output_maps_soybean\37S_C400TBLH3 - 1S_C400TBLH0_plot_Delta_S.png
#
# ============================================================
# Pair  3/48:  49S_C400TBLH123 - 1S_C400TBLH0
# ============================================================
#   Grid cells: 2,423  |  Positive-flag: 0
#   Saved: c:\BioCro_DSSAT_WOFOST_Egorov_etal_paper-main\data\output_maps_soybean\49S_C400TBLH123 - 1S_C400TBLH0_plot_Delta_S.png
#
# ============================================================
# Pair  4/48:  14S_C400T1.5H1 - 2S_C400T1.5H0
# ============================================================
#   Grid cells: 2,423  |  Positive-flag: 0
#   Saved: c:\BioCro_DSSAT_WOFOST_Egorov_etal_paper-main\data\output_maps_soybean\14S_C400T1.5H1 - 2S_C400T1.5H0_plot_Delta_S.png
#
# ============================================================
# Pair  5/48:  26S_C400T1.5H2 - 2S_C400T1.5H0
# ============================================================
#   Grid cells: 2,423  |  Positive-flag: 0
#   Saved: c:\BioCro_DSSAT_WOFOST_Egorov_etal_paper-main\data\output_maps_soybean\26S_C400T1.5H2 - 2S_C400T1.5H0_plot_Delta_S.png
#
# ============================================================
# Pair  6/48:  38S_C400T1.5H3 - 2S_C400T1.5H0
# ============================================================
#   Grid cells: 2,423  |  Positive-flag: 0
#   Saved: c:\BioCro_DSSAT_WOFOST_Egorov_etal_paper-main\data\output_maps_soybean\38S_C400T1.5H3 - 2S_C400T1.5H0_plot_Delta_S.png
#
# ============================================================
# Pair  7/48:  50S_C400T1.5H123 - 2S_C400T1.5H0
# ============================================================
#   Grid cells: 2,423  |  Positive-flag: 0
#   Saved: c:\BioCro_DSSAT_WOFOST_Egorov_etal_paper-main\data\output_maps_soybean\50S_C400T1.5H123 - 2S_C400T1.5H0_plot_Delta_S.png
#
# ============================================================
# Pair  8/48:  15S_C400T2.5H1 - 3S_C400T2.5H0
# ============================================================
#   Grid cells: 2,423  |  Positive-flag: 0
#   Saved: c:\BioCro_DSSAT_WOFOST_Egorov_etal_paper-main\data\output_maps_soybean\15S_C400T2.5H1 - 3S_C400T2.5H0_plot_Delta_S.png
#
# ============================================================
# Pair  9/48:  27S_C400T2.5H2 - 3S_C400T2.5H0
# ============================================================
#   Grid cells: 2,423  |  Positive-flag: 0
#   Saved: c:\BioCro_DSSAT_WOFOST_Egorov_etal_paper-main\data\output_maps_soybean\27S_C400T2.5H2 - 3S_C400T2.5H0_plot_Delta_S.png
#
# ============================================================
# Pair 10/48:  39S_C400T2.5H3 - 3S_C400T2.5H0
# ============================================================
#   Grid cells: 2,423  |  Positive-flag: 0
#   Saved: c:\BioCro_DSSAT_WOFOST_Egorov_etal_paper-main\data\output_maps_soybean\39S_C400T2.5H3 - 3S_C400T2.5H0_plot_Delta_S.png
#
# ============================================================
# Pair 11/48:  51S_C400T2.5H123 - 3S_C400T2.5H0
# ============================================================
#   Grid cells: 2,423  |  Positive-flag: 0
#   Saved: c:\BioCro_DSSAT_WOFOST_Egorov_etal_paper-main\data\output_maps_soybean\51S_C400T2.5H123 - 3S_C400T2.5H0_plot_Delta_S.png
#
# ============================================================
# Pair 12/48:  16S_C400T4H1 - 4S_C400T4H0
# ============================================================
#   Grid cells: 2,423  |  Positive-flag: 0
#   Saved: c:\BioCro_DSSAT_WOFOST_Egorov_etal_paper-main\data\output_maps_soybean\16S_C400T4H1 - 4S_C400T4H0_plot_Delta_S.png
#
# ============================================================
# Pair 13/48:  28S_C400T4H2 - 4S_C400T4H0
# ============================================================
#   Grid cells: 2,423  |  Positive-flag: 0
#   Saved: c:\BioCro_DSSAT_WOFOST_Egorov_etal_paper-main\data\output_maps_soybean\28S_C400T4H2 - 4S_C400T4H0_plot_Delta_S.png
#
# ============================================================
# Pair 14/48:  40S_C400T4H3 - 4S_C400T4H0
# ============================================================
#   Grid cells: 2,423  |  Positive-flag: 0
#   Saved: c:\BioCro_DSSAT_WOFOST_Egorov_etal_paper-main\data\output_maps_soybean\40S_C400T4H3 - 4S_C400T4H0_plot_Delta_S.png
#
# ============================================================
# Pair 15/48:  52S_C400T4H123 - 4S_C400T4H0
# ============================================================
#   Grid cells: 2,423  |  Positive-flag: 0
#   Saved: c:\BioCro_DSSAT_WOFOST_Egorov_etal_paper-main\data\output_maps_soybean\52S_C400T4H123 - 4S_C400T4H0_plot_Delta_S.png
#
# ============================================================
# Pair 16/48:  17S_C600TBLH1 - 5S_C600TBLH0
# ============================================================
#   Grid cells: 2,423  |  Positive-flag: 0
#   Saved: c:\BioCro_DSSAT_WOFOST_Egorov_etal_paper-main\data\output_maps_soybean\17S_C600TBLH1 - 5S_C600TBLH0_plot_Delta_S.png
#
# ============================================================
# Pair 17/48:  29S_C600TBLH2 - 5S_C600TBLH0
# ============================================================
#   Grid cells: 2,423  |  Positive-flag: 0
#   Saved: c:\BioCro_DSSAT_WOFOST_Egorov_etal_paper-main\data\output_maps_soybean\29S_C600TBLH2 - 5S_C600TBLH0_plot_Delta_S.png
#
# ============================================================
# Pair 18/48:  41S_C600TBLH3 - 5S_C600TBLH0
# ============================================================
#   Grid cells: 2,423  |  Positive-flag: 15
# C:\Users\yaron\AppData\Local\Temp\ipykernel_4960\190363248.py:34: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   pts['geometry'] = pts.centroid
#   Saved: c:\BioCro_DSSAT_WOFOST_Egorov_etal_paper-main\data\output_maps_soybean\41S_C600TBLH3 - 5S_C600TBLH0_plot_Delta_S.png
#
# ============================================================
# Pair 19/48:  53S_C600TBLH123 - 5S_C600TBLH0
# ============================================================
#   Grid cells: 2,423  |  Positive-flag: 0
